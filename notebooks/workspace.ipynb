# %%
# INTERACTIVE PLOTS (only if you code locally, unfortunately)
# This cell can take some minutes to run
# You should only need to run this cell once and not everytime you open the script
# In case the plotting of the data below does not work because of the error "Error displaying widget: model not found"
# you'll probably have to restart your kernel once more.

# IMPORTANT: After running this cell, restart your kernel
# uncomment the next two lines for interactive plots
#!jupyter labextension install @jupyter-widgets/jupyterlab-manager jupyter-leaflet
# !pip install install nodejs
# Out:
# (Deprecated) Installing extensions with the jupyter labextension install command is now deprecated and will be removed in a future major version of JupyterLab.
#
# Users should manage prebuilt extensions with package managers like pip and conda, and extension authors are encouraged to distribute their extensions as prebuilt packages
# /home/suno/.conda/envs/mhealth/lib/python3.10/site-packages/jupyterlab/debuglog.py:54: UserWarning: An error occurred.
#   warnings.warn("An error occurred.")
# /home/suno/.conda/envs/mhealth/lib/python3.10/site-packages/jupyterlab/debuglog.py:55: UserWarning: ValueError: Please install Node.js and npm before continuing installation. You may be able to install Node.js from your package manager, from conda, or directly from the Node.js website (https://nodejs.org).
#   warnings.warn(msg[-1].strip())
# /home/suno/.conda/envs/mhealth/lib/python3.10/site-packages/jupyterlab/debuglog.py:56: UserWarning: See the log file for details: /tmp/jupyterlab-debug-wj8pydvj.log
#   warnings.warn(f"See the log file for details: {log_path!s}")
# ERROR: Could not find a version that satisfies the requirement install (from versions: none)
# ERROR: No matching distribution found for install

# %%
import matplotlib.pyplot as plt

# You may change the mhealth_activity module but your algorithm must support the original version
from mhealth_activity import Recording, Trace, Activity, WatchLocation, Path

# For interactive plots, uncomment the following line
# %matplotlib widget

# %% [markdown]
# # Reading sensor data from PKL file
#
# Create an instance of the <code>Recording</code> class that manages the data from a file

# %%
recording = Recording('/home/suno/MHAM/Exercise_3/data/train/train_trace_000.pkl')

# The data is stored inside a dictionary (access: recording.data["key"])
print("\r\nAvailable data traces:")
print(list(recording.data.keys()))

if not(recording.labels is None):
    print("\r\nLabels: ")
    print(recording.labels)

print(f"\r\nRecording:")
for key in list(recording.data.keys()):
    print(f'{key}: {recording.data[key]}')
# Out:
# Available data traces:
# ['phone_mx', 'gx', 'altitude', 'phone_rotx', 'phone_gravy', 'phone_gz', 'phone_my', 'timestamp', 'gz', 'ax', 'my', 'phone_pressure', 'phone_gravx', 'phone_gy', 'phone_orientationx', 'temperature', 'phone_az', 'mz', 'az', 'gy', 'phone_mz', 'phone_light', 'phone_rotm', 'phone_ax', 'packetNumber', 'phone_orientationz', 'phone_gravz', 'phone_gx', 'phone_lax', 'phone_laz', 'phone_rotz', 'ay', 'phone_roty', 'phone_lay', 'mx', 'phone_ay', 'phone_orientationy']
#
# Labels:
# {'path_idx': 0, 'watch_loc': 0, 'step_count': -1, 'activities': {'standing': False, 'walking': True, 'running': False, 'cycling': False}}
#
# Recording:
# phone_mx: Trace(title='phone_mx', total_time=576.04, samplerate=98.81, max_update_gap=0.25)
# gx: Trace(title='gx', total_time=576.04, samplerate=200.01, max_update_gap=0.02)
# altitude: Trace(title='altitude', total_time=576.04, samplerate=12.50, max_update_gap=58.32)
# phone_rotx: Trace(title='phone_rotx', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_gravy: Trace(title='phone_gravy', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_gz: Trace(title='phone_gz', total_time=576.04, samplerate=197.35, max_update_gap=0.18)
# phone_my: Trace(title='phone_my', total_time=576.04, samplerate=98.81, max_update_gap=0.25)
# timestamp: Trace(title='timestamp', total_time=576.04, samplerate=12.50, max_update_gap=0.40)
# gz: Trace(title='gz', total_time=576.04, samplerate=200.01, max_update_gap=0.02)
# ax: Trace(title='ax', total_time=576.04, samplerate=200.01, max_update_gap=0.04)
# my: Trace(title='my', total_time=576.04, samplerate=12.50, max_update_gap=2.21)
# phone_pressure: Trace(title='phone_pressure', total_time=576.04, samplerate=5.48, max_update_gap=0.63)
# phone_gravx: Trace(title='phone_gravx', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_gy: Trace(title='phone_gy', total_time=576.04, samplerate=197.35, max_update_gap=0.18)
# phone_orientationx: Trace(title='phone_orientationx', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# temperature: Trace(title='temperature', total_time=576.04, samplerate=12.50, max_update_gap=225.81)
# phone_az: Trace(title='phone_az', total_time=576.04, samplerate=197.35, max_update_gap=0.18)
# mz: Trace(title='mz', total_time=576.04, samplerate=12.50, max_update_gap=2.39)
# az: Trace(title='az', total_time=576.04, samplerate=200.01, max_update_gap=0.05)
# gy: Trace(title='gy', total_time=576.04, samplerate=200.01, max_update_gap=0.02)
# phone_mz: Trace(title='phone_mz', total_time=576.04, samplerate=98.81, max_update_gap=0.25)
# phone_light: Trace(title='phone_light', total_time=576.04, samplerate=5.44, max_update_gap=0.54)
# phone_rotm: Trace(title='phone_rotm', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_ax: Trace(title='phone_ax', total_time=576.04, samplerate=197.35, max_update_gap=0.18)
# packetNumber: Trace(title='packetNumber', total_time=576.04, samplerate=12.50, max_update_gap=0.40)
# phone_orientationz: Trace(title='phone_orientationz', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_gravz: Trace(title='phone_gravz', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_gx: Trace(title='phone_gx', total_time=576.04, samplerate=197.35, max_update_gap=0.18)
# phone_lax: Trace(title='phone_lax', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_laz: Trace(title='phone_laz', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_rotz: Trace(title='phone_rotz', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# ay: Trace(title='ay', total_time=576.04, samplerate=200.01, max_update_gap=0.06)
# phone_roty: Trace(title='phone_roty', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# phone_lay: Trace(title='phone_lay', total_time=576.04, samplerate=98.66, max_update_gap=0.22)
# mx: Trace(title='mx', total_time=576.04, samplerate=12.50, max_update_gap=2.21)
# phone_ay: Trace(title='phone_ay', total_time=576.04, samplerate=197.35, max_update_gap=0.18)
# phone_orientationy: Trace(title='phone_orientationy', total_time=576.04, samplerate=98.66, max_update_gap=0.22)

# %%
print("ACTIVITIES")
for activity in Activity:
    if activity.value in recording.labels["activities"]:
        print(f"{activity.name} is contained in the recording, thus '{activity.name.lower()}': True")
    else:
        print(f"{activity.name} is NOT contained in the recording, thus '{activity.name.lower()}': False")

print("\r\nWATCH LOCATION")
print(f"The LilyGo was worn on the {WatchLocation(recording.labels['watch_loc']).name.lower()}.")

print("\r\nPATH IDX")
print(f"The participant completed {Path(recording.labels['path_idx']).name.lower()}.")

print("\r\nSTEP COUNT")
if "step_count" in recording.labels:
    if recording.labels["step_count"] != -1:
        print(f"The participant performed {recording.labels['step_count']} steps.")
    else:
        print("The step count is not available.")
else:
    print("The step count is not available.")
# Out:
# ACTIVITIES
# STANDING is NOT contained in the recording, thus 'standing': False
# WALKING is NOT contained in the recording, thus 'walking': False
# RUNNING is NOT contained in the recording, thus 'running': False
# CYCLING is NOT contained in the recording, thus 'cycling': False
#
# WATCH LOCATION
# The LilyGo was worn on the wrist.
#
# PATH IDX
# The participant completed path_0.
#
# STEP COUNT
# The step count is not available.

# %% [markdown]
# ## Working with timeseries
# Every value in this dictionary holds a <code>Trace</code> object to manage the data from one sensor

# %%
recording = Recording('/home/suno/MHAM/Exercise_3/data/example/medium_walk.pkl')  # Second example file: data/example/short_walk.pkl

# X-axis of the LILYGO accelerometer
ax = recording.data['ax']

print(f"Name of sensor: '{ax.title}'")
print(f"Sample rate: {int(ax.samplerate)} Hz")
print(f"Recording length: {ax.total_time} seconds")
print(f"Timestamp of recording: {ax.raw_timestamps[0][1]}")
print("\nGetting a time series:")
print(" Time           x-Accel")
for x, t in list(zip(ax.timestamps, ax.values))[:20]:
    print(f"{x: .3f}s \t{t:.5f}g")
# Out:
# Name of sensor: 'ax'
# Sample rate: 200 Hz
# Recording length: 136.789 seconds
# Timestamp of recording: 1645184293057
#
# Getting a time series:
#  Time           x-Accel
#  0.000s 	-0.41138g
#  0.005s 	-0.40381g
#  0.010s 	-0.38452g
#  0.015s 	-0.35645g
#  0.020s 	-0.32031g
#  0.025s 	-0.29248g
#  0.030s 	-0.25635g
#  0.035s 	-0.21118g
#  0.040s 	-0.17676g
#  0.045s 	-0.16138g
#  0.050s 	-0.14624g
#  0.055s 	-0.13989g
#  0.060s 	-0.14624g
#  0.065s 	-0.14209g
#  0.070s 	-0.15576g
#  0.075s 	-0.16821g
#  0.080s 	-0.17773g
#  0.085s 	-0.19019g
#  0.090s 	-0.19946g
#  0.095s 	-0.20752g

# %% [markdown]
# # Plotting

# %%
# Display a simple plot
recording.plot(['ax'])

# %%
# Plot multiple axes at the same time
# It's also possible to give titles to the y-axis and plots
recording.plot(['ax', 'ay', 'az'], ylabels=['acceleration [g]'], labels=['Acc X', 'Acc Y', 'Acc Z'])

# %%
# Plot multiple sensors and multiple axes at the same time
recording.plot([['ax', 'ay', 'az'], ['gx', 'gy', 'gz'], ['mx', 'my', 'mz'], ['altitude'], ['speed']], 
             ylabels=['acceleration [g]', 'rot. vel. [deg/s]', 'field strength [µT]', 'altitude [m]', 'speed [m/s]'],
             labels=[['Acc X', 'Acc Y', 'Acc Z'], ['Gyro X', 'Gyro Y', 'Gyro Z'], ['Mag X', 'Mag Y', 'Mag Z'], ['Altitude'], ['Speed']])

# %%
# How to Zoom In: use start_s and end_s to specify the time range in seconds
# start_s: start of the range you want to plot (in seconds since the start of the trace)
# end_s: end of the range you want to plot (in seconds since the start of the trace)
recording.plot([['ax', 'ay', 'az'], ['gx', 'gy', 'gz'], ['mx', 'my', 'mz'], ['altitude'], ['speed']], 
             ylabels=['acceleration [g]', 'rot. vel. [deg/s]', 'field strength [µT]', 'altitude [m]', 'speed [m/s]'],
             labels=[['Acc X', 'Acc Y', 'Acc Z'], ['Gyro X', 'Gyro Y', 'Gyro Z'], ['Mag X', 'Mag Y', 'Mag Z'], ['Altitude'], ['Speed']],
               start_s=10, end_s=70)

# %% [markdown]
# # Display GPS data

# %%
# Recording must contain gps data
assert('latitude' in recording.data and 'longitude' in recording.data)

plot_map_zurich = True

# Visualize the path of the trace
fig, ax = plt.subplots(figsize = (11,6))
ax.scatter(recording.data['longitude'].values, recording.data['latitude'].values, zorder=1, alpha= 0.9, c='b', s=10)
ax.set_title('Visualization of the path')

if plot_map_zurich:
    # Bounding coordinates for map
    BBox = (8.5373,8.5593,
            47.3673, 47.3880)
    # Load map of Zurich
    ruh_m = plt.imread('/home/suno/MHAM/Exercise_3/documents/mapzurich.png')
    ax.set_title('GPS visualization in Zurich')
    ax.set_xlim(BBox[0],BBox[1])
    ax.set_ylim(BBox[2],BBox[3])
    ax.imshow(ruh_m, zorder=0, extent = BBox)

# %% [markdown]
# # Generate computed traces
#
# Small example that adds an accelerometer magnitude trace
#
# <code>Trace.from_modified(cls, title: str, values: np.ndarray, timestamps: np.ndarray, time_offset: float = 0)</code> can be used to save a new or modified trace for the Recording object.
#
# <code>title</code>: Title for this collection of data.<br>
# <code>values</code>: modified values<br>
# <code>timestamps</code>: array of timestamps, one timestamp per value, usually directly taken from the original data<br>
# <code>offset</code>: optional offset in case the "raw_timestamps" should match the original data<br>
#
# Note: This change is only executed locally and not saved to the pkl file. Everytime you reload your dataset, you have to re-execute this steps. Alternatively, you can save a copy of your modified Recording using <code>save_to_pkl</code> (please be careful not to introduce errors in your origninal training set).

# %%
# Trace must contain lilygo accelerometer data
assert('ax' in recording.data and 'ay' in recording.data and 'az' in recording.data)
# And those traces must be of the same length
assert(len(recording.data['ax'].values) == len(recording.data['ay'].values)  and len(recording.data['ax'].values) == len(recording.data['az'].values) )

magn = (recording.data['ax'].values**2 + recording.data['ay'].values**2 + recording.data['az'].values**2)**0.5

recording.data['a_mag'] = Trace.from_modified('Accelerometer magnitude', magn, recording.data['ax'].timestamps, recording.data['ax'].raw_timestamps[0][1])

recording.plot([['ax', 'ay', 'az'], ['a_mag']])

# %% [markdown]
# # FYI: How Timestamps Are Handled (You Probably Don't Need This)
#
# Every time the smartphone receives a package via Bluetooth from the LilyGo smartwatch, up to 16 sensor values are stored at once, together with the current timestamp. Therefore, not every sensor reading has a perfectly defined timestamp that is 100% accurate.
#
# Each <code>Trace</code> contains a list of <code>raw_timestamps</code>, which are tuples of the type `(trace index, timestamp)`.
#
# The timestamps are standard Unix timestamps in milliseconds.
#
# For example, the first two entries indicate "The 0th value arrived at 1645184293057, the 16th value at 1645184293144."

# %%
recording.data["ax"].raw_timestamps
# Out:
# [(0, 1645184293057),
#  (14640, 1645184366281),
#  (14656, 1645184366360),
#  (14672, 1645184366484),
#  (14688, 1645184366524),
#  (14704, 1645184366607),
#  (14720, 1645184366688),
#  (14736, 1645184366771),
#  (14752, 1645184366860),
#  (14768, 1645184366938),
#  (14784, 1645184367019),
#  (14800, 1645184367102),
#  (14816, 1645184367185),
#  (14832, 1645184367272),
#  (14848, 1645184367307),
#  (14864, 1645184367403),
#  (14880, 1645184367472),
#  (14896, 1645184367558),
#  (14912, 1645184367637),
#  (14928, 1645184367765),
#  (14944, 1645184367802),
#  (14960, 1645184367927),
#  (14976, 1645184367969),
#  (14992, 1645184368052),
#  (15008, 1645184368132),
#  (15024, 1645184368215),
#  (15040, 1645184368296),
#  (15056, 1645184368427),
#  (15072, 1645184368463),
#  (15088, 1645184368544),
#  (15104, 1645184368630),
#  (15120, 1645184368675),
#  (15136, 1645184368750),
#  (15152, 1645184368832),
#  (15168, 1645184368915),
#  (15184, 1645184369000),
#  (15200, 1645184369081),
#  (15216, 1645184369163),
#  (15232, 1645184369246),
#  (15248, 1645184369330),
#  (15264, 1645184369411),
#  (15280, 1645184369493),
#  (15296, 1645184369575),
#  (15312, 1645184369658),
#  (15328, 1645184369745),
#  (15344, 1645184369836),
#  (15360, 1645184369908),
#  (15376, 1645184369988),
#  (15392, 1645184370032),
#  (15408, 1645184370113),
#  (15424, 1645184370195),
#  (15440, 1645184370278),
#  (15456, 1645184370362),
#  (15472, 1645184370442),
#  (15488, 1645184370527),
#  (15504, 1645184370649),
#  (15520, 1645184370689),
#  (15536, 1645184370773),
#  (15552, 1645184370859),
#  (15568, 1645184370945),
#  (15584, 1645184371020),
#  (15600, 1645184371102),
#  (15616, 1645184371187),
#  (15632, 1645184371268),
#  (15648, 1645184371311),
#  (15664, 1645184371392),
#  (15680, 1645184371478),
#  (15696, 1645184371556),
#  (15712, 1645184371641),
#  (15728, 1645184371722),
#  (15744, 1645184371805),
#  (15760, 1645184371888),
#  (15776, 1645184371969),
#  (15792, 1645184372051),
#  (15808, 1645184372134),
#  (15824, 1645184372216),
#  (15840, 1645184372339),
#  (15856, 1645184372423),
#  (15872, 1645184372462),
#  (15888, 1645184372548),
#  (15904, 1645184372628),
#  (15920, 1645184372671),
#  (15936, 1645184372836),
#  (15952, 1645184372844),
#  (15968, 1645184372916),
#  (15984, 1645184373001),
#  ...]

# %%
recording.data['ax'].raw_timestamps[-1][1]-recording.data['ax'].raw_timestamps[0][1]

# %% [markdown]
# The LilyGo uses a FIFO with a constant sampling rate, so it should be a fair assumption, that the delay between two consecutive readings is always the same.
#
# By default the <code>Trace.timestamps</code> array is linearly interpolated between the first and the last timestamp (<code>linspace(0, last_timestamp, num=len(values))</code>)

# %%
# Compare "ideal" interpolated timestamps against actual received timestamps
recording.data['ideal_ts'] = Trace('ideal_ts', 
                                   [recording.data['timestamp'].values[0], recording.data['timestamp'].values[-1]], 
                                   [(0,recording.data['timestamp'].values[0]), 
                                    (len(recording.data['timestamp'].values), recording.data['timestamp'].values[-1])])
recording.plot(['timestamp', 'ideal_ts'], labels=['Received timestamps', 'Interpolated Timestamps'], ylabels=['ms'])
